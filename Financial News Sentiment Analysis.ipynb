# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import transformers
import datasets
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
device = torch.device("mps")
from sklearn.metrics import f1_score,accuracy_score

# %% [markdown]
# # 0 -> negative 1-> positive

# %% [markdown]
# ### load with datasets

# %%
from datasets import load_dataset
stock_sentiment = load_dataset("csv",data_files='fin_sent_updated.csv')

# %%
stock_sentiment = stock_sentiment.remove_columns(['Unnamed: 0','wrd_len'])

# %%
stock_sentiment = stock_sentiment['train'].train_test_split(train_size=0.8)

# %%
stock_sentiment = stock_sentiment.rename_columns({'Sentiment':'label','Sentence':'text'})

# %%
stock_sentiment
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'text'],
#         num_rows: 87000
#     })
#     test: Dataset({
#         features: ['label', 'text'],
#         num_rows: 21750
#     })
# })

# %% [markdown]
# ### explore dataset

# %%
stock_sentiment.set_format("pd")

# %%
df = stock_sentiment['train'][:]

# %%
plt.title('Label distribution')
sns.countplot(x='label',data=df,palette='viridis',gap=0.3,width=0.7)
# Out:
# <Axes: title={'center': 'Label distribution'}, xlabel='label', ylabel='count'>

# %%
df['wrd_len'] = df['text'].str.split().apply(len)
plt.title('Words per sample')
sns.boxplot(y='wrd_len',data=df,hue='label',fill=False,gap=0.2,width=0.7,color='black',linewidth=0.6)
# Out:
# <Axes: title={'center': 'Words per sample'}, ylabel='wrd_len'>

# %%
stock_sentiment.reset_format()

# %% [markdown]
# ### First Iteration BERT

# %%
model_path = 'bert-base-uncased'

# %% [markdown]
# ### tokenizer

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path)

# %%
tokenizer("this is a sample text")
# Out:
# {'input_ids': [101, 2023, 2003, 1037, 7099, 3793, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
def apply_tokenizer(batch):
    return tokenizer(batch['text'],padding=True,truncation=True)

# %%
stock_sentiment = stock_sentiment.map(apply_tokenizer,batched=True,batch_size=None)
# Out:
# Map:   0%|          | 0/87000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/21750 [00:00<?, ? examples/s]

# %%
stock_sentiment.set_format("pt",columns=['input_ids','attention_mask','label'])

# %% [markdown]
# ### model

# %%
from transformers import AutoModelForSequenceClassification
num_labels = 2
model = (AutoModelForSequenceClassification.from_pretrained(model_path,num_labels=num_labels).to(device))
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### compute metrics

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels,preds)
    acc = accuracy_score(labels,preds)
    return {'f1':f1,'acc':acc}

# %% [markdown]
# ### training hyperparams

# %%
from transformers import TrainingArguments
model_name = 'Stock_Sentiment_BERT'
batch_size = 2
logging_steps = len(stock_sentiment['train'])//batch_size
#weight decay helps reduce overfitting
weight_decay = 0.01
training_args = TrainingArguments(output_dir=model_name,
                                 per_device_eval_batch_size=batch_size,
                                 per_device_train_batch_size=batch_size,
                                 disable_tqdm=False,
                                 push_to_hub=True,
                                 logging_steps=logging_steps,
                                 log_level="error",
                                 eval_strategy="epoch",
                                 weight_decay=weight_decay,
                                 num_train_epochs=3,
                                 learning_rate=2e-5
                                 )

# %%
from transformers import Trainer
trainer = Trainer(args=training_args,
                 model=model,
                 compute_metrics=compute_metrics,
                 train_dataset=stock_sentiment['train'],
                 eval_dataset=stock_sentiment['test'],
                 tokenizer = tokenizer)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='22' max='130500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [    22/130500 00:02 < 4:52:56, 7.42 it/s, Epoch 0.00/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 trainer.train()
#
# File /opt/anaconda3/envs/myenv/lib/python3.10/site-packages/transformers/trainer.py:2114, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2111 try:
#    2112     # Disable progress bars when uploading models during checkpoints to avoid polluting stdout
#    2113     hf_hub_utils.disable_progress_bars()
# -> 2114     return inner_training_loop(
#    2115         args=args,
#    2116         resume_from_checkpoint=resume_from_checkpoint,
#    2117         trial=trial,
#    2118         ignore_keys_for_eval=ignore_keys_for_eval,
#    2119     )
#    2120 finally:
#    2121     hf_hub_utils.enable_progress_bars()
#
# File /opt/anaconda3/envs/myenv/lib/python3.10/site-packages/transformers/trainer.py:2486, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2480 with context():
#    2481     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2483 if (
#    2484     args.logging_nan_inf_filter
#    2485     and not is_torch_xla_available()
# -> 2486     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2487 ):
#    2488     # if loss is nan or inf simply add the average of previous logged losses
#    2489     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#    2490 else:
#
# KeyboardInterrupt:

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
